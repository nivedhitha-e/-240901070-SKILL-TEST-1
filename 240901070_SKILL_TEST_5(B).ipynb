# %%
Problem Statement:
You are provided with a CSV file named healthcare_data.csv that contains patient
information and their medical history. Write a Python script using Pandas to perform the
following tasks:
1. Load the dataset and display the column names along with their data types.
2. Calculate and display the average age of the patients.
3. Analyze the distribution of diagnoses to understand the most common medical
conditions in the dataset.
You may use Matplotlib or Seaborn to visualize the diagnosis distribution if desired.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Patient_ID': ['D001','D002','D003','D004','D005','D006','D007','D008'],
    'Name': ['Alice','Bob','Clara','David','Ella','Frank','Grace','Henry'],
    'Age': [54,61,47,59,65,50,56,62],
    'Gender': ['F','M','F','M','F','M','F','M'],
    'Diagnosis': ['Diabetes','Hypertension','Diabetes','Asthma',
                  'Diabetes','Hypertension','Asthma','Diabetes']
}
df = pd.DataFrame(data)
print("Columns:\n", df.columns)
print("\nData Types:\n", df.dtypes)
print("\nAverage Age:", df['Age'].mean())

diagnosis_counts = df['Diagnosis'].value_counts()
print("\nDiagnosis Distribution:\n", diagnosis_counts)
diagnosis_counts.plot(kind='bar')

plt.xlabel("Diagnosis")
plt.ylabel("Number of Patients")
plt.title("Diagnosis Distribution")
plt.show()
# Out:
# Columns:
#  Index(['Patient_ID', 'Name', 'Age', 'Gender', 'Diagnosis'], dtype='object')
#
# Data Types:
#  Patient_ID    object
# Name          object
# Age            int64
# Gender        object
# Diagnosis     object
# dtype: object
#
# Average Age: 56.75
#
# Diagnosis Distribution:
#  Diagnosis
# Diabetes        4
# Hypertension    2
# Asthma          2
# Name: count, dtype: int64
